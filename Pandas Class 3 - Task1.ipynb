# %%
#Q1. Read this dataset in pandas,mysql and mongodb

# %%
# read dataset in pandas

# %%
import pandas as pd

# %%
df = pd.read_csv('FitBit data.csv')

# %%
df.head()
# Out:
#            Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 0  1503960366   2016-03-25       11004           7.11             7.11
# 1  1503960366   2016-03-26       17609          11.55            11.55
# 2  1503960366   2016-03-27       12736           8.53             8.53
# 3  1503960366   2016-03-28       13231           8.93             8.93
# 4  1503960366   2016-03-29       12041           7.85             7.85
#
#    LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# 0                       0.0                2.57                      0.46
# 1                       0.0                6.92                      0.73
# 2                       0.0                4.66                      0.16
# 3                       0.0                3.19                      0.79
# 4                       0.0                2.16                      1.09
#
#    LightActiveDistance  SedentaryActiveDistance  VeryActiveMinutes  \
# 0                 4.07                      0.0                 33
# 1                 3.91                      0.0                 89
# 2                 3.71                      0.0                 56
# 3                 4.95                      0.0                 39
# 4                 4.61                      0.0                 28
#
#    FairlyActiveMinutes  LightlyActiveMinutes  SedentaryMinutes  Calories  \
# 0                   12                   205               804      1819
# 1                   17                   274               588      2154
# 2                    5                   268               605      1944
# 3                   20                   224              1080      1932
# 4                   28                   243               763      1886
#
#    Total Active Minutes
# 0                   250
# 1                   380
# 2                   329
# 3                   283
# 4                   299

# %%
# # While creating a data in mysql don't use manual approach to create it, always use a automation to create a table in mysql

# %%
import mysql.connector as conn

mydb  = conn.connect(host = "localhost",user = "root",passwd = "data@scientist21#*",database="FitBit1_track")
print(mydb)
# Out:
# <mysql.connector.connection_cext.CMySQLConnection object at 0x000001D038035B20>

# %%
data = pd.read_sql_query("""select * from Fitbit_Data""",mydb)
# Out:
# C:\Users\Sonali Thakur\Documents\Python Scripts\lib\site-packages\pandas\io\sql.py:761: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(

# %%
data.head()
# Out:
#              Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 0  1.503960e+09         None     17609.0          11.55            11.55
# 1  1.503960e+09         None     12736.0           8.53             8.53
# 2  1.503960e+09         None     12736.0           8.53             8.53
# 3  1.503960e+09         None     13231.0           8.93             8.93
# 4  1.503960e+09         None     12041.0           7.85             7.85
#
#    LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# 0                       0.0                6.92                      0.73
# 1                       0.0                4.66                      0.16
# 2                       0.0                4.66                      0.16
# 3                       0.0                3.19                      0.79
# 4                       0.0                2.16                      1.09
#
#    LightActiveDistance  SedentaryActiveDistance  VeryActiveMinutes  \
# 0                 3.91                      0.0               89.0
# 1                 3.71                      0.0               56.0
# 2                 3.71                      0.0               56.0
# 3                 4.95                      0.0               39.0
# 4                 4.61                      0.0               28.0
#
#    FairlyActiveMinutes  LightlyActiveMinutes  SedentaryMinutes  Calories
# 0                 17.0                 274.0             588.0    2154.0
# 1                  5.0                 268.0             605.0    1944.0
# 2                  5.0                 268.0             605.0    1944.0
# 3                 20.0                 224.0            1080.0    1932.0
# 4                 28.0                 243.0             763.0    1886.0

# %%
# read data from mongodb

# %%
import pymongo as pymongo

# %%
client = pymongo.MongoClient("mongodb+srv://Sonali:datascientist@cluster0.u4r6hcl.mongodb.net/?retryWrites=true&w=majority")
database = client['csvconverter']
collection = database['data']
x = collection.find()
for data in x:
    print(x)
# Out:
# <pymongo.cursor.Cursor object at 0x000001D03161FDF0>
# <pymongo.cursor.Cursor object at 0x000001D03161FDF0>
# <pymongo.cursor.Cursor object at 0x000001D03161FDF0>
# <pymongo.cursor.Cursor object at 0x000001D03161FDF0>
# <pymongo.cursor.Cursor object at 0x000001D03161FDF0>
# <pymongo.cursor.Cursor object at 0x000001D03161FDF0>
# <pymongo.cursor.Cursor object at 0x000001D03161FDF0>
# <pymongo.cursor.Cursor object at 0x000001D03161FDF0>
# <pymongo.cursor.Cursor object at 0x000001D03161FDF0>
# <pymongo.cursor.Cursor object at 0x000001D03161FDF0>
# <pymongo.cursor.Cursor object at 0x000001D03161FDF0>
# <pymongo.cursor.Cursor object at 0x000001D03161FDF0>
# <pymongo.cursor.Cursor object at 0x000001D03161FDF0>
# <pymongo.cursor.Cursor object at 0x000001D03161FDF0>
# <pymongo.cursor.Cursor object at 0x000001D03161FDF0>
# <pymongo.cursor.Cursor object at 0x000001D03161FDF0>
# <pymongo.cursor.Cursor object at 0x000001D03161FDF0>
# <pymongo.cursor.Cursor object at 0x000001D03161FDF0>
# <pymongo.cursor.Cursor object at 0x000001D03161FDF0>
# <pymongo.cursor.Cursor object at 0x000001D03161FDF0>
# <pymongo.cursor.Cursor object at 0x000001D03161FDF0>
# <pymongo.cursor.Cursor object at 0x000001D03161FDF0>
# <pymongo.cursor.Cursor object at 0x000001D03161FDF0>
# <pymongo.cursor.Cursor object at 0x000001D03161FDF0>
# <pymongo.cursor.Cursor object at 0x000001D03161FDF0>
# <pymongo.cursor.Cursor object at 0x000001D03161FDF0>
# <pymongo.cursor.Cursor object at 0x000001D03161FDF0>
# <pymongo.cursor.Cursor object at 0x000001D03161FDF0>
# <pymongo.cursor.Cursor object at 0x000001D03161FDF0>
# <pymongo.cursor.Cursor object at 0x000001D03161FDF0>
# <pymongo.cursor.Cursor object at 0x000001D03161FDF0>
# <pymongo.cursor.Cursor object at 0x000001D03161FDF0>
# <pymongo.cursor.Cursor object at 0x000001D03161FDF0>
# <pymongo.cursor.Cursor object at 0x000001D03161FDF0>
# <pymongo.cursor.Cursor object at 0x000001D03161FDF0>
# <pymongo.cursor.Cursor object at 0x000001D03161FDF0>
# <pymongo.cursor.Cursor object at 0x000001D03161FDF0>
# <pymongo.cursor.Cursor object at 0x000001D03161FDF0>
# <pymongo.cursor.Cursor object at 0x000001D03161FDF0>
# <pymongo.cursor.Cursor object at 0x000001D03161FDF0>
# <pymongo.cursor.Cursor object at 0x000001D03161FDF0>
# <pymongo.cursor.Cursor object at 0x000001D03161FDF0>
# <pymongo.cursor.Cursor object at 0x000001D03161FDF0>
# <pymongo.cursor.Cursor object at 0x000001D03161FDF0>
# <pymongo.cursor.Cursor object at 0x000001D03161FDF0>
# <pymongo.cursor.Cursor object at 0x000001D03161FDF0>
# <pymongo.cursor.Cursor object at 0x000001D03161FDF0>
# <pymongo.cursor.Cursor object at 0x000001D03161FDF0>
# <pymongo.cursor.Cursor object at 0x000001D03161FDF0>
# <pymongo.cursor.Cursor object at 0x000001D03161FDF0>
# <pymongo.cursor.Cursor object at 0x000001D03161FDF0>
# <pymongo.cursor.Cursor object at 0x000001D03161FDF0>
# <pymongo.cursor.Cursor object at 0x000001D03161FDF0>
# <pymongo.cursor.Cursor object at 0x000001D03161FDF0>
# <pymongo.cursor.Cursor object at 0x000001D03161FDF0>
# <pymongo.cursor.Cursor object at 0x000001D03161FDF0>
# <pymongo.cursor.Cursor object at 0x000001D03161FDF0>
# <pymongo.cursor.Cursor object at 0x000001D03161FDF0>
# <pymongo.cursor.Cursor object at 0x000001D03161FDF0>
# <pymongo.cursor.Cursor object at 0x000001D03161FDF0>
# <pymongo.cursor.Cursor object at 0x000001D03161FDF0>
# <pymongo.cursor.Cursor object at 0x000001D03161FDF0>
# <pymongo.cursor.Cursor object at 0x000001D03161FDF0>
# <pymongo.cursor.Cursor object at 0x000001D03161FDF0>
# <pymongo.cursor.Cursor object at 0x000001D03161FDF0>
# <pymongo.cursor.Cursor object at 0x000001D03161FDF0>
# <pymongo.cursor.Cursor object at 0x000001D03161FDF0>
# <pymongo.cursor.Cursor object at 0x000001D03161FDF0>
# <pymongo.cursor.Cursor object at 0x000001D03161FDF0>
# <pymongo.cursor.Cursor object at 0x000001D03161FDF0>
# <pymongo.cursor.Cursor object at 0x000001D03161FDF0>
# <pymongo.cursor.Cursor object at 0x000001D03161FDF0>
# <pymongo.cursor.Cursor object at 0x000001D03161FDF0>
# <pymongo.cursor.Cursor object at 0x000001D03161FDF0>
# <pymongo.cursor.Cursor object at 0x000001D03161FDF0>
# <pymongo.cursor.Cursor object at 0x000001D03161FDF0>
# <pymongo.cursor.Cursor object at 0x000001D03161FDF0>
# <pymongo.cursor.Cursor object at 0x000001D03161FDF0>
# <pymongo.cursor.Cursor object at 0x000001D03161FDF0>
# <pymongo.cursor.Cursor object at 0x000001D03161FDF0>
# <pymongo.cursor.Cursor object at 0x000001D03161FDF0>
# <pymongo.cursor.Cursor object at 0x000001D03161FDF0>
# <pymongo.cursor.Cursor object at 0x000001D03161FDF0>
# <pymongo.cursor.Cursor object at 0x000001D03161FDF0>
# <pymongo.cursor.Cursor object at 0x000001D03161FDF0>
# <pymongo.cursor.Cursor object at 0x000001D03161FDF0>
# <pymongo.cursor.Cursor object at 0x000001D03161FDF0>
# <pymongo.cursor.Cursor object at 0x000001D03161FDF0>
# <pymongo.cursor.Cursor object at 0x000001D03161FDF0>
# <pymongo.cursor.Cursor object at 0x000001D03161FDF0>
# <pymongo.cursor.Cursor object at 0x000001D03161FDF0>
# <pymongo.cursor.Cursor object at 0x000001D03161FDF0>
# <pymongo.cursor.Cursor object at 0x000001D03161FDF0>
# <pymongo.cursor.Cursor object at 0x000001D03161FDF0>
# <pymongo.cursor.Cursor object at 0x000001D03161FDF0>
# <pymongo.cursor.Cursor object at 0x000001D03161FDF0>
# <pymongo.cursor.Cursor object at 0x000001D03161FDF0>
# <pymongo.cursor.Cursor object at 0x000001D03161FDF0>
# <pymongo.cursor.Cursor object at 0x000001D03161FDF0>
# <pymongo.cursor.Cursor object at 0x000001D03161FDF0>
# <pymongo.cursor.Cursor object at 0x000001D03161FDF0>
# <pymongo.cursor.Cursor object at 0x000001D03161FDF0>
# <pymongo.cursor.Cursor object at 0x000001D03161FDF0>
# <pymongo.cursor.Cursor object at 0x000001D03161FDF0>
# <pymongo.cursor.Cursor object at 0x000001D03161FDF0>
# <pymongo.cursor.Cursor object at 0x000001D03161FDF0>
# <pymongo.cursor.Cursor object at 0x000001D03161FDF0>
# <pymongo.cursor.Cursor object at 0x000001D03161FDF0>
# <pymongo.cursor.Cursor object at 0x000001D03161FDF0>
# <pymongo.cursor.Cursor object at 0x000001D03161FDF0>
# <pymongo.cursor.Cursor object at 0x000001D03161FDF0>
# <pymongo.cursor.Cursor object at 0x000001D03161FDF0>
# <pymongo.cursor.Cursor object at 0x000001D03161FDF0>
# <pymongo.cursor.Cursor object at 0x000001D03161FDF0>
# <pymongo.cursor.Cursor object at 0x000001D03161FDF0>
# <pymongo.cursor.Cursor object at 0x000001D03161FDF0>
# <pymongo.cursor.Cursor object at 0x000001D03161FDF0>
# <pymongo.cursor.Cursor object at 0x000001D03161FDF0>
# <pymongo.cursor.Cursor object at 0x000001D03161FDF0>
# <pymongo.cursor.Cursor object at 0x000001D03161FDF0>
# <pymongo.cursor.Cursor object at 0x000001D03161FDF0>
# <pymongo.cursor.Cursor object at 0x000001D03161FDF0>
# <pymongo.cursor.Cursor object at 0x000001D03161FDF0>
# <pymongo.cursor.Cursor object at 0x000001D03161FDF0>
# <pymongo.cursor.Cursor object at 0x000001D03161FDF0>
# <pymongo.cursor.Cursor object at 0x000001D03161FDF0>
# <pymongo.cursor.Cursor object at 0x000001D03161FDF0>
# <pymongo.cursor.Cursor object at 0x000001D03161FDF0>
# <pymongo.cursor.Cursor object at 0x000001D03161FDF0>
# <pymongo.cursor.Cursor object at 0x000001D03161FDF0>
# <pymongo.cursor.Cursor object at 0x000001D03161FDF0>
# <pymongo.cursor.Cursor object at 0x000001D03161FDF0>
# <pymongo.cursor.Cursor object at 0x000001D03161FDF0>
# <pymongo.cursor.Cursor object at 0x000001D03161FDF0>
# <pymongo.cursor.Cursor object at 0x000001D03161FDF0>
# <pymongo.cursor.Cursor object at 0x000001D03161FDF0>
# <pymongo.cursor.Cursor object at 0x000001D03161FDF0>
# <pymongo.cursor.Cursor object at 0x000001D03161FDF0>
# <pymongo.cursor.Cursor object at 0x000001D03161FDF0>
# <pymongo.cursor.Cursor object at 0x000001D03161FDF0>
# <pymongo.cursor.Cursor object at 0x000001D03161FDF0>
# <pymongo.cursor.Cursor object at 0x000001D03161FDF0>
# <pymongo.cursor.Cursor object at 0x000001D03161FDF0>
# <pymongo.cursor.Cursor object at 0x000001D03161FDF0>
# <pymongo.cursor.Cursor object at 0x000001D03161FDF0>
# <pymongo.cursor.Cursor object at 0x000001D03161FDF0>

# %%
# Convert all the data available in dataset to timestamp format in pandas and in sql convert it into date format

# %%
df['ActivityDate'] = pd.to_datetime(df['ActivityDate'])

# %%
type(df['ActivityDate'][0])
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
df.head()
# Out:
#            Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 0  1503960366   2016-03-25       11004           7.11             7.11
# 1  1503960366   2016-03-26       17609          11.55            11.55
# 2  1503960366   2016-03-27       12736           8.53             8.53
# 3  1503960366   2016-03-28       13231           8.93             8.93
# 4  1503960366   2016-03-29       12041           7.85             7.85
#
#    LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# 0                       0.0                2.57                      0.46
# 1                       0.0                6.92                      0.73
# 2                       0.0                4.66                      0.16
# 3                       0.0                3.19                      0.79
# 4                       0.0                2.16                      1.09
#
#    LightActiveDistance  SedentaryActiveDistance  VeryActiveMinutes  \
# 0                 4.07                      0.0                 33
# 1                 3.91                      0.0                 89
# 2                 3.71                      0.0                 56
# 3                 4.95                      0.0                 39
# 4                 4.61                      0.0                 28
#
#    FairlyActiveMinutes  LightlyActiveMinutes  SedentaryMinutes  Calories
# 0                   12                   205               804      1819
# 1                   17                   274               588      2154
# 2                    5                   268               605      1944
# 3                   20                   224              1080      1932
# 4                   28                   243               763      1886

# %%
# Find out in this data how many unique id we have

# %%
df['Id'].nunique()
# Out:
# 35

# %%
# Which id is one of the most active id that you have in whole dataset

# %%
df.groupby('Id')['VeryActiveMinutes'].sum().idxmax()
# Out:
# 8053475328

# %%
# How many of them have not logged there activity find out in terms of number of ids

# %%
df.groupby('Id')['LoggedActivitiesDistance'].sum()<1
# Out:
# Id
# 1503960366     True
# 1624580081     True
# 1644430081     True
# 1844505072     True
# 1927972279     True
# 2022484408     True
# 2026352035     True
# 2320127002     True
# 2347167796     True
# 2873212765     True
# 2891001357    False
# 3372868164     True
# 3977333714     True
# 4020332650     True
# 4057192912     True
# 4319703577     True
# 4388161847     True
# 4445114986     True
# 4558609924     True
# 4702921684     True
# 5553957443     True
# 5577150313     True
# 6117666160     True
# 6290855005     True
# 6391747486    False
# 6775888955     True
# 6962181067    False
# 7007744171    False
# 7086361926     True
# 8053475328     True
# 8253242879     True
# 8378563200    False
# 8583815059     True
# 8792009665     True
# 8877689391     True
# Name: LoggedActivitiesDistance, dtype: bool

# %%
# Find out who is the laziest person id that we have in the dataset

# %%
df.groupby('Id')['VeryActiveMinutes'].sum().idxmin()
# Out:
# 1927972279

# %%
#  Explore over an internet that how much calories burnt is required for a healthy person and find out how many healthy person 
#  we have in our dataset (2200 calories/day)

# %%
df.groupby('Id')['Calories'].sum().apply(lambda x:x>2200*7).value_counts()
# Out:
# True     34
# False     1
# Name: Calories, dtype: int64

# %%
# How many persons are not a regular with respect to activit try to find out those

# %%
df[df['TotalSteps']==0]
# Out:
#              Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 51   1844505072   2016-04-04           0            0.0              0.0
# 52   1844505072   2016-04-05           0            0.0              0.0
# 59   1844505072   2016-04-12           0            0.0              0.0
# 96   2320127002   2016-04-01           0            0.0              0.0
# 97   2320127002   2016-04-02           0            0.0              0.0
# ..          ...          ...         ...            ...              ...
# 402  8253242879   2016-04-02           0            0.0              0.0
# 403  8253242879   2016-04-03           0            0.0              0.0
# 404  8253242879   2016-04-04           0            0.0              0.0
# 405  8253242879   2016-04-05           0            0.0              0.0
# 412  8253242879   2016-04-12           0            0.0              0.0
#
#      LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# 51                        0.0                 0.0                       0.0
# 52                        0.0                 0.0                       0.0
# 59                        0.0                 0.0                       0.0
# 96                        0.0                 0.0                       0.0
# 97                        0.0                 0.0                       0.0
# ..                        ...                 ...                       ...
# 402                       0.0                 0.0                       0.0
# 403                       0.0                 0.0                       0.0
# 404                       0.0                 0.0                       0.0
# 405                       0.0                 0.0                       0.0
# 412                       0.0                 0.0                       0.0
#
#      LightActiveDistance  SedentaryActiveDistance  VeryActiveMinutes  \
# 51                   0.0                      0.0                  0
# 52                   0.0                      0.0                  0
# 59                   0.0                      0.0                  0
# 96                   0.0                      0.0                  0
# 97                   0.0                      0.0                  0
# ..                   ...                      ...                ...
# 402                  0.0                      0.0                  0
# 403                  0.0                      0.0                  0
# 404                  0.0                      0.0                  0
# 405                  0.0                      0.0                  0
# 412                  0.0                      0.0                  0
#
#      FairlyActiveMinutes  LightlyActiveMinutes  SedentaryMinutes  Calories  \
# 51                     0                     0               669      1347
# 52                     0                     0              1440      1347
# 59                     0                     0               426       399
# 96                     0                     0              1440      1324
# 97                     0                     0              1440      1324
# ..                   ...                   ...               ...       ...
# 402                    0                     0              1440      1429
# 403                    0                     0              1440      1429
# 404                    0                     0              1440      1429
# 405                    0                     0              1440      1429
# 412                    0                     0              1440         0
#
#      Total Active Minutes
# 51                      0
# 52                      0
# 59                      0
# 96                      0
# 97                      0
# ..                    ...
# 402                     0
# 403                     0
# 404                     0
# 405                     0
# 412                     0
#
# [61 rows x 16 columns]

# %%
# Who is the third most active person in this dataset find out those in pandas

# %%
df.groupby('Id')['VeryActiveMinutes'].sum().sort_values(ascending=False)[2:3]
# Out:
# Id
# 8877689391    802
# Name: VeryActiveMinutes, dtype: int64

# %%
# Who is the fifth most laziest person available in dataset find it out

# %%
df.groupby('Id')['VeryActiveMinutes'].sum().sort_values()[4:5]
# Out:
# Id
# 6117666160    5
# Name: VeryActiveMinutes, dtype: int64

# %%
# What is the total cummulative calories burn for a perso find out

# %%
df.groupby('Id')["Calories"].sum()
# Out:
# Id
# 1503960366    34128
# 1624580081    25705
# 1644430081    29164
# 1844505072    19391
# 1927972279    27048
# 2022484408    29704
# 2026352035    16266
# 2320127002    18385
# 2347167796    30320
# 2873212765    20349
# 2891001357    18187
# 3372868164    18603
# 3977333714    16777
# 4020332650    98412
# 4057192912    60913
# 4319703577    23931
# 4388161847    14442
# 4445114986    31617
# 4558609924    21962
# 4702921684    42322
# 5553957443    21630
# 5577150313    36303
# 6117666160    20993
# 6290855005    21656
# 6391747486    15868
# 6775888955    24523
# 6962181067    29249
# 7007744171    31525
# 7086361926    26124
# 8053475328    31825
# 8253242879    17556
# 8378563200    40274
# 8583815059    19130
# 8792009665    24884
# 8877689391    41414
# Name: Calories, dtype: int64
